# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('MNIST.csv')
data
# Out:
#       c0  c1  c2  c3  c4  c5  c6  c7  c8  c9  ...  c55  c56  c57  c58  c59  \
# 0      0   0   5  13   9   1   0   0   0   0  ...    0    0    0    6   13
# 1      0   0   0  12  13   5   0   0   0   0  ...    0    0    0    0   11
# 2      0   0   0   4  15  12   0   0   0   0  ...    0    0    0    0    3
# 3      0   0   7  15  13   1   0   0   0   8  ...    0    0    0    7   13
# 4      0   0   0   1  11   0   0   0   0   0  ...    0    0    0    0    2
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 1792   0   0   4  10  13   6   0   0   0   1  ...    0    0    0    2   14
# 1793   0   0   6  16  13  11   1   0   0   0  ...    0    0    0    6   16
# 1794   0   0   1  11  15   1   0   0   0   0  ...    0    0    0    2    9
# 1795   0   0   2  10   7   0   0   0   0   0  ...    0    0    0    5   12
# 1796   0   0  10  14   8   1   0   0   0   2  ...    0    0    1    8   12
#
#       c60  c61  c62  c63  target
# 0      10    0    0    0       0
# 1      16   10    0    0       1
# 2      11   16    9    0       2
# 3      13    9    0    0       3
# 4      16    4    0    0       4
# ...   ...  ...  ...  ...     ...
# 1792   15    9    0    0       9
# 1793   14    6    0    0       0
# 1794   13    6    0    0       8
# 1795   16   12    0    0       9
# 1796   14   12    1    0       8
#
# [1797 rows x 65 columns]

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (1437, 64) (1437,) (360, 64) (360,)

# %%
from sklearn.neural_network import MLPClassifier
mlp=MLPClassifier()
mlp.fit(x_train,y_train)
# Out:
# MLPClassifier()

# %%
mlp.score(x_test,y_test)
# Out:
# 0.9833333333333333

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()
p.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
p.score(x_test,y_test)
# Out:
# 0.9527777777777777

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(50,activation='relu',input_shape=(64,)))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# /opt/anaconda3/envs/matin.detecy/lib/python3.9/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 50)             │         3,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 10)             │           510 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,760 (14.69 KB)
#  Trainable params: 3,760 (14.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=25)
# Out:
# Epoch 1/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - accuracy: 0.9967 - loss: 0.0343
# Epoch 2/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.9969 - loss: 0.0258
# Epoch 3/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - accuracy: 0.9970 - loss: 0.0266
# Epoch 4/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - accuracy: 0.9946 - loss: 0.0280
# Epoch 5/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - accuracy: 0.9972 - loss: 0.0213
# Epoch 6/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - accuracy: 0.9979 - loss: 0.0231
# Epoch 7/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - accuracy: 0.9987 - loss: 0.0188
# Epoch 8/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - accuracy: 0.9974 - loss: 0.0180
# Epoch 9/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - accuracy: 0.9996 - loss: 0.0174
# Epoch 10/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - accuracy: 0.9995 - loss: 0.0156
# Epoch 11/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - accuracy: 0.9995 - loss: 0.0139
# Epoch 12/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - accuracy: 1.0000 - loss: 0.0163
# Epoch 13/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 14/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 15/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 16/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - accuracy: 1.0000 - loss: 0.0113
# Epoch 17/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 18/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - accuracy: 0.9997 - loss: 0.0093
# Epoch 19/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 20/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 21/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 22/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 23/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 24/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 25/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - accuracy: 1.0000 - loss: 0.0065

# %%
a=data.iloc[490,:-1]
b=np.reshape(a,(1,64))
v=model.predict([b])
np.argmax(v)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# np.int64(6)

# %%
model.save('model.keras')

# %%
moodel=np.load('model.keras')
model
#a=data.iloc[490,:-1]
#b=np.reshape(a,(1,64))
#v=model.predict([b])
#np.argmax(v)
# Out:
# NpzFile 'model.keras' with keys: metadata.json, config.json, model.weights.h5
